# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)



def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))



vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.



data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])



batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, embed,
                               num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))


num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()


num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])


def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5241, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'term', 'originated', 'as', 'of']
# Initialized
# Average loss at step 0: 7.991473
# Nearest to its: automotive, harkonnen, transonic, fijian, ueshiba, seriously, morihei, subgenius,
# Nearest to during: anthroposophical, beliefs, bhra, streak, makran, astrology, lsi, dinah,
# Nearest to over: nyasa, deletions, rowdy, squandered, tupelo, thematic, detector, lordship,
# Nearest to people: sextus, moreau, moveable, decius, reprisals, jiva, moderating, fermions,
# Nearest to by: endl, contextual, barrett, tropospheric, updike, fishery, fullmetal, fleshed,
# Nearest to but: enhance, expendable, kriegsmarine, considers, sunderland, pounded, dumpling, medici,
# Nearest to often: labrador, spa, glaciation, winnings, drifted, symbolics, simulation, browne,
# Nearest to while: rader, marine, investment, hyman, tree, peerages, charred, oxley,
# Nearest to called: middens, cladistics, subdue, ryu, devon, veda, feng, confidence,
# Nearest to the: mitch, fujimori, osiris, caenorhabditis, arbitrators, ecotourism, bovary, charming,
# Nearest to th: squared, linn, acrobatics, albeit, gesserit, jacobites, exposing, aznar,
# Nearest to were: mahindra, entities, prokaryote, mistakenly, diagnosed, torts, toppling, relatively,
# Nearest to all: dryope, auditory, blows, disjunction, cistercian, overlap, music, proclaim,
# Nearest to also: phobia, folkestone, possum, slug, crucial, implosive, rajput, thrill,
# Nearest to their: ean, dzhokhar, prognosis, harshly, chromatin, crouch, deoxygenated, tds,
# Nearest to from: schismatic, namath, paulsen, flaubert, choral, pronunciations, postalveolar, untrained,
# Average loss at step 2000: 4.369984
# Average loss at step 4000: 3.863215
# Average loss at step 6000: 3.786046
# Average loss at step 8000: 3.688239
# Average loss at step 10000: 3.617598
# Nearest to its: the, their, manure, his, combined, freedom, chaining, seriously,
# Nearest to during: chandragupta, dinah, hamza, beliefs, car, commercialization, drinker, fitna,
# Nearest to over: nyasa, tupelo, thematic, deletions, lordship, tito, on, instigator,
# Nearest to people: fitz, decius, fermions, mangeshkar, moreau, moderating, those, repopulated,
# Nearest to by: was, underwriting, from, into, banchan, as, kidneys, with,
# Nearest to but: irv, or, loki, racine, and, solent, fib, brummell,
# Nearest to often: cowdery, anarchists, gypsys, drifted, spa, simulation, it, gluten,
# Nearest to while: peerages, marine, eg, dissenting, cardano, eisenhower, tree, shaw,
# Nearest to called: confidence, flowers, slashes, alkali, survived, middens, moulin, withholding,
# Nearest to the: a, its, this, his, their, mondo, an, bluetooth,
# Nearest to th: romanized, four, rbis, linn, acrobatics, gesserit, jacobites, albeit,
# Nearest to were: are, was, mahindra, have, carbohydrates, lookup, evoke, endomorphisms,
# Nearest to all: some, bilinear, weser, cumulative, appointing, conflict, middleweight, overlap,
# Nearest to also: not, which, random, undermining, attaches, it, steep, parson,
# Nearest to their: his, the, its, arena, annuals, canary, webcomic, fic,
# Nearest to from: in, at, into, by, schismatic, manic, paulsen, pronunciations,
# Average loss at step 12000: 3.606329
# Average loss at step 14000: 3.568801
# Average loss at step 16000: 3.408980
# Average loss at step 18000: 3.456205
# Average loss at step 20000: 3.538877
# Nearest to its: their, his, the, freedom, chaining, plaid, this, her,
# Nearest to during: chandragupta, car, dinah, in, on, fitna, after, hamza,
# Nearest to over: tupelo, nyasa, tito, thematic, fatalism, neorealism, movie, pamphlets,
# Nearest to people: those, fitz, fermions, women, tirelessly, pranks, redistricting, harmonization,
# Nearest to by: were, underwriting, through, be, for, wie, filmography, fragmentary,
# Nearest to but: though, since, and, that, which, when, although, however,
# Nearest to often: who, also, commonly, cowdery, anarchists, gluten, spa, gypsys,
# Nearest to while: when, eg, marine, paymaster, dissenting, shaw, dukkha, if,
# Nearest to called: moulin, alkali, survived, devon, confidence, elvira, ebbinghaus, flap,
# Nearest to the: their, its, this, any, an, a, another, these,
# Nearest to th: romanized, two, one, inverness, aussie, jacobites, acrobatics, bc,
# Nearest to were: are, was, had, have, by, and, is, be,
# Nearest to all: many, some, several, these, gambeson, importance, cumulative, crest,
# Nearest to also: which, not, now, generally, veganism, still, often, random,
# Nearest to their: his, its, the, her, persist, many, canary, some,
# Nearest to from: into, in, through, at, between, koan, for, falconiformes,
# Average loss at step 22000: 3.500840
# Average loss at step 24000: 3.493690
# Average loss at step 26000: 3.484576
# Average loss at step 28000: 3.481976
# Average loss at step 30000: 3.503326
# Nearest to its: their, the, his, her, supermarkets, immanent, dijkstra, rung,
# Nearest to during: in, after, before, under, circulation, of, evaded, capitolina,
# Nearest to over: thematic, rowdy, tupelo, fatalism, unconsciously, sans, jeans, movie,
# Nearest to people: those, women, fermions, fitz, others, newcomer, years, constructivist,
# Nearest to by: in, were, from, under, underwriting, and, lucca, checks,
# Nearest to but: however, although, though, when, and, which, while, since,
# Nearest to often: sometimes, commonly, also, generally, who, cowdery, now, there,
# Nearest to while: when, but, if, is, shaw, where, eg, paymaster,
# Nearest to called: alkali, elvira, devon, flap, survived, based, kodak, cladistics,
# Nearest to the: their, its, his, a, her, redshifted, our, pisa,
# Nearest to th: six, one, nd, inverness, aussie, romanized, jacobites, bc,
# Nearest to were: are, have, was, had, by, been, be, gash,
# Nearest to all: some, many, these, importance, several, christendom, haber, inflate,
# Nearest to also: which, now, often, still, generally, already, sometimes, tracked,
# Nearest to their: his, its, the, her, some, these, our, many,
# Nearest to from: into, in, choral, through, under, of, and, by,
# Average loss at step 32000: 3.503879
# Average loss at step 34000: 3.495684
# Average loss at step 36000: 3.457437
# Average loss at step 38000: 3.304504
# Average loss at step 40000: 3.438712
# Nearest to its: their, his, the, immanent, dijkstra, her, your, supermarkets,
# Nearest to during: after, in, before, at, under, since, on, paracetamol,
# Nearest to over: thematic, tupelo, jeans, qf, fatalism, rowdy, from, yr,
# Nearest to people: those, women, men, fermions, abercrombie, others, closure, inositol,
# Nearest to by: clapton, with, underwriting, through, checks, jaffna, ladies, autobiographies,
# Nearest to but: however, and, although, though, does, it, where, which,
# Nearest to often: sometimes, commonly, generally, also, who, usually, now, which,
# Nearest to while: when, are, although, where, and, among, but, bluish,
# Nearest to called: flap, alkali, elvira, stereo, referred, hooking, pitchfork, devon,
# Nearest to the: their, its, his, any, a, this, another, some,
# Nearest to th: nd, inverness, jacobites, bc, st, aussie, jurist, acrobatics,
# Nearest to were: are, have, was, had, been, many, being, including,
# Nearest to all: these, many, importance, several, prosecutors, some, because, metaphase,
# Nearest to also: still, often, which, generally, sometimes, now, usually, murad,
# Nearest to their: his, its, her, the, some, any, these, webcomic,
# Nearest to from: into, through, under, falconiformes, in, pronunciations, of, inflate,
# Average loss at step 42000: 3.436474
# Average loss at step 44000: 3.453678
# Average loss at step 46000: 3.452901
# Average loss at step 48000: 3.351917
# Average loss at step 50000: 3.385296
# Nearest to its: their, his, the, her, your, dijkstra, chaining, immanent,
# Nearest to during: after, in, at, before, under, when, since, through,
# Nearest to over: fatalism, jeans, thematic, bothwell, unconsciously, finals, alleviating, wins,
# Nearest to people: men, those, women, fermions, children, players, jews, netanyahu,
# Nearest to by: through, underwriting, checks, from, with, under, was, in,
# Nearest to but: however, although, though, while, and, since, fib, when,
# Nearest to often: sometimes, generally, usually, commonly, widely, also, typically, now,
# Nearest to while: when, and, although, where, but, though, for, is,
# Nearest to called: referred, flap, elvira, stereo, hooking, pitchfork, alkali, humanly,
# Nearest to the: their, this, its, his, some, a, puma, diddy,
# Nearest to th: nd, st, bc, twentieth, one, ad, acrobatics, six,
# Nearest to were: are, have, was, had, being, be, been, bragg,
# Nearest to all: these, many, each, both, some, those, every, flashpoint,
# Nearest to also: still, which, now, often, sometimes, usually, generally, murad,
# Nearest to their: his, its, her, the, some, any, your, these,
# Nearest to from: into, through, in, falconiformes, choral, until, by, under,
# Average loss at step 52000: 3.438387
# Average loss at step 54000: 3.424911
# Average loss at step 56000: 3.441755
# Average loss at step 58000: 3.390070
# Average loss at step 60000: 3.393964
# Nearest to its: their, his, the, her, your, whose, penalties, chaining,
# Nearest to during: after, before, under, in, since, when, although, at,
# Nearest to over: thematic, jeans, fatalism, alleviating, hypnotized, in, when, wins,
# Nearest to people: men, others, women, those, individuals, jews, players, money,
# Nearest to by: through, fragmentary, underwriting, including, memnon, from, under, with,
# Nearest to but: however, although, though, and, fib, when, while, airing,
# Nearest to often: sometimes, usually, commonly, generally, also, now, typically, widely,
# Nearest to while: when, although, though, where, after, stupid, but, kurdish,
# Nearest to called: used, flap, pitchfork, referred, shelters, optimum, elvira, stereo,
# Nearest to the: their, its, a, this, each, any, miletus, his,
# Nearest to th: bc, nd, ad, six, twentieth, st, one, acrobatics,
# Nearest to were: are, was, have, had, including, been, those, although,
# Nearest to all: those, many, both, these, each, some, any, every,
# Nearest to also: still, now, sometimes, often, generally, usually, typically, frequently,
# Nearest to their: its, his, her, the, your, some, whose, my,
# Nearest to from: into, through, pronunciations, in, choral, falconiformes, by, within,
# Average loss at step 62000: 3.244224
# Average loss at step 64000: 3.255554
# Average loss at step 66000: 3.410950
# Average loss at step 68000: 3.396456
# Average loss at step 70000: 3.358021
# Nearest to its: their, his, the, her, your, whose, immanent, dijkstra,
# Nearest to during: after, before, in, under, at, since, within, through,
# Nearest to over: fatalism, carmilla, through, alleviating, wins, canard, unconsciously, jeans,
# Nearest to people: men, women, others, jews, those, children, individuals, things,
# Nearest to by: through, fragmentary, from, with, gting, be, autobiographies, including,
# Nearest to but: however, although, though, which, while, that, and, there,
# Nearest to often: sometimes, usually, commonly, generally, now, typically, frequently, also,
# Nearest to while: although, though, however, when, where, but, if, after,
# Nearest to called: referred, used, pitchfork, hooking, humanly, stereo, shelters, lung,
# Nearest to the: its, their, any, this, a, each, these, our,
# Nearest to th: bc, twentieth, nd, ad, st, rd, acrobatics, jacobites,
# Nearest to were: are, was, had, be, have, been, mushrooms, renderer,
# Nearest to all: many, some, any, each, every, various, those, because,
# Nearest to also: still, now, often, sometimes, usually, which, generally, rida,
# Nearest to their: its, his, her, the, your, our, some, my,
# Nearest to from: through, into, pronunciations, in, by, before, falconiformes, until,
# Average loss at step 72000: 3.377792
# Average loss at step 74000: 3.343222
# Average loss at step 76000: 3.314949
# Average loss at step 78000: 3.353142
# Average loss at step 80000: 3.378739
# Nearest to its: their, his, her, the, your, immanent, whose, chaining,
# Nearest to during: after, before, in, when, at, despite, within, through,
# Nearest to over: fatalism, carmilla, almost, conspicuous, template, tupelo, around, canard,
# Nearest to people: men, women, others, children, jews, individuals, things, those,
# Nearest to by: including, through, sobib, clapton, from, wie, thresholds, autobiographies,
# Nearest to but: although, however, though, while, and, or, than, which,
# Nearest to often: sometimes, usually, commonly, typically, generally, frequently, now, also,
# Nearest to while: although, though, however, and, but, when, after, where,
# Nearest to called: referred, named, used, known, stereo, shelters, pitchfork, considered,
# Nearest to the: their, its, this, his, a, notional, conformations, antares,
# Nearest to th: bc, twentieth, nd, ad, rd, acrobatics, inverness, fourth,
# Nearest to were: are, was, had, have, been, being, although, became,
# Nearest to all: many, any, every, both, each, several, some, various,
# Nearest to also: still, often, now, sometimes, generally, usually, which, never,
# Nearest to their: its, his, her, your, our, the, my, these,
# Nearest to from: through, into, pronunciations, within, in, during, before, falconiformes,
# Average loss at step 82000: 3.410818
# Average loss at step 84000: 3.411411
# Average loss at step 86000: 3.389544
# Average loss at step 88000: 3.352380
# Average loss at step 90000: 3.361984
# Nearest to its: their, his, her, the, your, whose, favouring, immanent,
# Nearest to during: after, in, before, at, until, within, under, when,
# Nearest to over: around, fatalism, within, template, through, almost, carmilla, conspicuous,
# Nearest to people: women, men, students, children, jews, others, players, orders,
# Nearest to by: through, without, clapton, fragmentary, including, when, under, wessel,
# Nearest to but: however, although, and, though, while, fib, which, he,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, also, now,
# Nearest to while: although, though, when, however, but, where, before, after,
# Nearest to called: used, referred, stereo, named, known, considered, shelters, pitchfork,
# Nearest to the: its, this, their, a, his, any, whose, diddy,
# Nearest to th: bc, nd, twentieth, rd, one, ad, st, seven,
# Nearest to were: are, was, had, have, while, been, although, renderer,
# Nearest to all: many, both, several, every, some, these, any, various,
# Nearest to also: still, often, now, generally, which, sometimes, usually, never,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to from: through, into, before, during, pronunciations, falconiformes, towards, maximized,
# Average loss at step 92000: 3.399243
# Average loss at step 94000: 3.253864
# Average loss at step 96000: 3.358759
# Average loss at step 98000: 3.242001
# Average loss at step 100000: 3.358167
# Nearest to its: their, his, the, her, your, whose, chaining, immanent,
# Nearest to during: after, in, before, through, at, until, since, throughout,
# Nearest to over: around, within, carmilla, template, fatalism, through, between, metric,
# Nearest to people: women, men, children, jews, others, students, players, things,
# Nearest to by: through, including, without, when, during, under, been, clapton,
# Nearest to but: however, although, and, though, while, which, than, fib,
# Nearest to often: sometimes, usually, commonly, generally, typically, frequently, now, widely,
# Nearest to while: although, when, though, but, and, before, after, where,
# Nearest to called: referred, used, named, stereo, megaliths, shelters, optimum, humanly,
# Nearest to the: their, its, his, your, a, this, hollingworth, whose,
# Nearest to th: nd, twentieth, bc, st, rd, jacobites, fourth, inverness,
# Nearest to were: are, was, although, have, these, had, been, include,
# Nearest to all: every, these, various, any, many, both, several, some,
# Nearest to also: still, now, often, generally, never, sometimes, usually, actually,
# Nearest to their: its, his, her, your, the, our, my, some,
# Nearest to from: through, into, during, in, falconiformes, choral, pronunciations, before,
