# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)

def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))

valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])


vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))


batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))


def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

embedding_size = 128 # Dimension of the embedding vector.
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size * vocabulary_size, embedding_size], -1.0, 1.0))
  
  
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))


  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_chars = train_data[:num_unrollings]
  train_inputs = zip(train_chars[:-1], train_chars[1:])
  train_labels = train_data[2:]  # labels are inputs shifted by twos time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    bigram_index = tf.argmax(i[0], dimension=1) + vocabulary_size * tf.argmax(i[1], dimension=1)
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, bigram_index)
    drop_i = tf.nn.dropout(i_embed, 0.7)
    output, state = lstm_cell(drop_i, output, state)
    drop_o = tf.nn.dropout(output, 0.7)
    outputs.append(drop_o)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    
    logits = tf.nn.xw_plus_b(tf.concat(outputs,0), w, b)
    
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
        logits=logits,labels=tf.concat(train_labels,0)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  #sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input = list()
  for _ in range(2):  
    sample_input.append(tf.placeholder(tf.float32, shape=[1, vocabulary_size]))
  samp_in_index = tf.argmax(sample_input[0], dimension=1) + vocabulary_size * tf.argmax(sample_input[1], dimension=1)
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, samp_in_index)
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))



import collections
num_steps = 10001
summary_frequency = 100

valid_batches = BatchGenerator(valid_text, 1, 2)

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[2:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          #feed = sample(random_distribution())
          feed = collections.deque(maxlen=2)
          for _ in range(2):  
            feed.append(random_distribution())
          
          sentence = characters(feed[0])[0] + characters(feed[1])[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({
                    sample_input[0]: feed[0],
                    sample_input[1]: feed[1]
                })
            
            feed.append(sample(prediction))
            sentence += characters(feed[1])[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({
                    sample_input[0]: b[0],
                    sample_input[1]: b[1]
            })
        valid_logprob = valid_logprob + logprob(predictions, b[2])
      print('Validation set perplexity: %.2f' % float(np.exp(
valid_logprob / valid_size)))
# Out:
# Found and verified text8.zip
# Data size 100000000
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl
# Unexpected character: ï
# 1 26 0 0
# a z
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']
# WARNING:tensorflow:From <ipython-input-2-e1a0d7630638>:268: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 3.307105 learning rate: 10.000000
# Minibatch perplexity: 27.31
# ================================================================================
# mkl   niv te  ax th  zbmoyzjze agd be cenp  eiibpulgr ymai d  hpejsodtasebkd  are
# knsecsuzj feaylyunszp n coefvc hrmjpx yjsawf fttmzha hnolatgl lwy c fozsg ro mafw
# wz  gncpieitikre jtfx  enaouz cpuffo  xyhg i a ms bce o xdlsicnv eq wqucna gswa
# cv re sdniar fg d otlpefthnyrl jw coovtjyeuboicyatwpyd  eeatq rrerlkooi nenndtu k
# paq jnkyol lj fjte  qbastd ggefg q ztnlzo wlvqxantpfguhsr trk wo s ie  wtu ktu a
# ================================================================================
# Validation set perplexity: 19.36
# Average loss at step 100: 2.474546 learning rate: 10.000000
# Minibatch perplexity: 9.80
# Validation set perplexity: 9.55
# Average loss at step 200: 2.191040 learning rate: 10.000000
# Minibatch perplexity: 9.08
# Validation set perplexity: 8.52
# Average loss at step 300: 2.124103 learning rate: 10.000000
# Minibatch perplexity: 8.24
# Validation set perplexity: 8.27
# Average loss at step 400: 2.071929 learning rate: 10.000000
# Minibatch perplexity: 8.39
# Validation set perplexity: 7.90
# Average loss at step 500: 2.039179 learning rate: 10.000000
# Minibatch perplexity: 7.11
# Validation set perplexity: 7.64
# Average loss at step 600: 2.044943 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 7.83
# Average loss at step 700: 2.006057 learning rate: 10.000000
# Minibatch perplexity: 7.37
# Validation set perplexity: 7.69
# Average loss at step 800: 1.979880 learning rate: 10.000000
# Minibatch perplexity: 6.93
# Validation set perplexity: 7.65
# Average loss at step 900: 2.000543 learning rate: 10.000000
# Minibatch perplexity: 8.36
# Validation set perplexity: 7.52
# Average loss at step 1000: 2.007294 learning rate: 10.000000
# Minibatch perplexity: 6.96
# ================================================================================
# uat whick ersion blphith of the dero zero two zeree of throud mivened of the mom
# bzero zero alit that knert phden be aine one a the ar is parnobion stagile a grfu
# bkl  cale king as fre conce hous fore sbeing jeu udeve reace enation count of mal
# vals recpicome in in sester verlies vore ctiontakem one seven devetictafenuch wit
# hxoly sey salt hown a relhlory guent the cheivection tion ogiwky spsing a of in f
# ================================================================================
# Validation set perplexity: 7.35
# Average loss at step 1100: 1.971289 learning rate: 10.000000
# Minibatch perplexity: 6.57
# Validation set perplexity: 7.42
# Average loss at step 1200: 1.951095 learning rate: 10.000000
# Minibatch perplexity: 6.25
# Validation set perplexity: 7.25
# Average loss at step 1300: 1.939551 learning rate: 10.000000
# Minibatch perplexity: 7.30
# Validation set perplexity: 7.42
# Average loss at step 1400: 1.958668 learning rate: 10.000000
# Minibatch perplexity: 7.53
# Validation set perplexity: 7.27
# Average loss at step 1500: 1.962887 learning rate: 10.000000
# Minibatch perplexity: 6.02
# Validation set perplexity: 7.37
# Average loss at step 1600: 1.972558 learning rate: 10.000000
# Minibatch perplexity: 6.75
# Validation set perplexity: 7.46
# Average loss at step 1700: 1.943140 learning rate: 10.000000
# Minibatch perplexity: 7.16
# Validation set perplexity: 7.33
# Average loss at step 1800: 1.912369 learning rate: 10.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 7.30
# Average loss at step 1900: 1.888597 learning rate: 10.000000
# Minibatch perplexity: 6.57
# Validation set perplexity: 7.09
# Average loss at step 2000: 1.942192 learning rate: 10.000000
# Minibatch perplexity: 7.24
# ================================================================================
# zrner ovestorii as b is cfnuding from dods by to operris the beans sothous ats us
# vgs sental paction cbula and the nation apprive obsince of quade minian a foov mi
# rfey c theed moventing in nktds kced in to bill sengreossies first one nine nine
# yloth two five nine nine one eight a alphis w peighter chruclents doeice war who
# cycnp luvu sfelied for lothe are kpzates of tend wolly seven posussion lation its
# ================================================================================
# Validation set perplexity: 7.11
# Average loss at step 2100: 1.937520 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.91
# Average loss at step 2200: 1.930863 learning rate: 10.000000
# Minibatch perplexity: 7.77
# Validation set perplexity: 7.06
# Average loss at step 2300: 1.894066 learning rate: 10.000000
# Minibatch perplexity: 6.39
# Validation set perplexity: 6.86
# Average loss at step 2400: 1.911458 learning rate: 10.000000
# Minibatch perplexity: 6.30
# Validation set perplexity: 6.89
# Average loss at step 2500: 1.931339 learning rate: 10.000000
# Minibatch perplexity: 6.76
# Validation set perplexity: 6.70
# Average loss at step 2600: 1.911307 learning rate: 10.000000
# Minibatch perplexity: 7.16
# Validation set perplexity: 6.70
# Average loss at step 2700: 1.923134 learning rate: 10.000000
# Minibatch perplexity: 5.89
# Validation set perplexity: 6.88
# Average loss at step 2800: 1.912793 learning rate: 10.000000
# Minibatch perplexity: 7.31
# Validation set perplexity: 6.85
# Average loss at step 2900: 1.906510 learning rate: 10.000000
# Minibatch perplexity: 7.36
# Validation set perplexity: 7.08
# Average loss at step 3000: 1.907614 learning rate: 10.000000
# Minibatch perplexity: 6.80
# ================================================================================
# for to wivh satvian her lable to with hin flable ended the orannks fricte apaside
# gspetting a pation soution arallication ithen infunna botholled to tran acwidle l
# cmllishiqually becamal puwter was rultem new nuch of pare keley spacs sh with ren
# qmal four show or dralus somer not the x pobastority mal bould envitf yang univer
# ns seight zero six five seven eight posenseverisish trivimel vi his all s londtro
# ================================================================================
# Validation set perplexity: 6.95
# Average loss at step 3100: 1.887210 learning rate: 10.000000
# Minibatch perplexity: 7.45
# Validation set perplexity: 6.89
# Average loss at step 3200: 1.906839 learning rate: 10.000000
# Minibatch perplexity: 7.36
# Validation set perplexity: 6.81
# Average loss at step 3300: 1.895321 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.88
# Average loss at step 3400: 1.930506 learning rate: 10.000000
# Minibatch perplexity: 7.18
# Validation set perplexity: 6.82
# Average loss at step 3500: 1.918340 learning rate: 10.000000
# Minibatch perplexity: 6.92
# Validation set perplexity: 6.92
# Average loss at step 3600: 1.927130 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 6.59
# Average loss at step 3700: 1.909589 learning rate: 10.000000
# Minibatch perplexity: 6.44
# Validation set perplexity: 6.69
# Average loss at step 3800: 1.899226 learning rate: 10.000000
# Minibatch perplexity: 7.03
# Validation set perplexity: 6.99
# Average loss at step 3900: 1.902093 learning rate: 10.000000
# Minibatch perplexity: 6.78
# Validation set perplexity: 6.89
# Average loss at step 4000: 1.905437 learning rate: 10.000000
# Minibatch perplexity: 6.28
# ================================================================================
# pzikeing at eactalish the ist poppe elphile a yging exection shards r exo of meti
# uzue enola is eure gys impopeple lated the lected seven eight eight zero zero zer
# ws gedy fors vock entable with macks or elgenindtopege s giscombing abote libever
# ffact which ctive jusited the defempeace betchan indeclars this be feell con char
# z these cipt elects onarobity posed very uments enminted cretare the mel distint
# ================================================================================
# Validation set perplexity: 6.78
# Average loss at step 4100: 1.898067 learning rate: 10.000000
# Minibatch perplexity: 6.44
# Validation set perplexity: 6.64
# Average loss at step 4200: 1.902862 learning rate: 10.000000
# Minibatch perplexity: 6.73
# Validation set perplexity: 6.59
# Average loss at step 4300: 1.883854 learning rate: 10.000000
# Minibatch perplexity: 6.54
# Validation set perplexity: 6.49
# Average loss at step 4400: 1.883912 learning rate: 10.000000
# Minibatch perplexity: 6.04
# Validation set perplexity: 6.55
# Average loss at step 4500: 1.883765 learning rate: 10.000000
# Minibatch perplexity: 6.54
# Validation set perplexity: 6.75
# Average loss at step 4600: 1.877952 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.70
# Average loss at step 4700: 1.903604 learning rate: 10.000000
# Minibatch perplexity: 6.77
# Validation set perplexity: 6.59
# Average loss at step 4800: 1.900060 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 6.59
# Average loss at step 4900: 1.898483 learning rate: 10.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 6.69
# Average loss at step 5000: 1.866000 learning rate: 1.000000
# Minibatch perplexity: 6.28
# ================================================================================
# uh formodh seath bours in the internality of is as sabill hall munary in  sever w
# rq bediasical smunix eern the beash vend gautes dword coents margan bebc it or se
# dnate in one nine piement zero occusies meoppon oright seven one congudings ont m
# svclfpzot in the prict were at the in been see zero zero zero zero zero zero mut
# can of the swuight a lehand tchavity the quy were dian constreupopeall not manhin
# ================================================================================
# Validation set perplexity: 6.92
# Average loss at step 5100: 1.882355 learning rate: 1.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 6.72
# Average loss at step 5200: 1.871846 learning rate: 1.000000
# Minibatch perplexity: 5.72
# Validation set perplexity: 6.62
# Average loss at step 5300: 1.849984 learning rate: 1.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 6.63
# Average loss at step 5400: 1.846773 learning rate: 1.000000
# Minibatch perplexity: 7.01
# Validation set perplexity: 6.63
# Average loss at step 5500: 1.848782 learning rate: 1.000000
# Minibatch perplexity: 6.73
# Validation set perplexity: 6.55
# Average loss at step 5600: 1.850524 learning rate: 1.000000
# Minibatch perplexity: 6.26
# Validation set perplexity: 6.54
# Average loss at step 5700: 1.850560 learning rate: 1.000000
# Minibatch perplexity: 6.05
# Validation set perplexity: 6.55
# Average loss at step 5800: 1.854804 learning rate: 1.000000
# Minibatch perplexity: 6.41
# Validation set perplexity: 6.55
# Average loss at step 5900: 1.852799 learning rate: 1.000000
# Minibatch perplexity: 6.73
# Validation set perplexity: 6.57
# Average loss at step 6000: 1.822150 learning rate: 1.000000
# Minibatch perplexity: 6.69
# ================================================================================
# zxn issiuvys extraced choand criloctor many of but of the dresed on recorrections
# gctive his it six six protest the film fashsr at the new year and tto by starkobi
# dly gumenting of is which were the slateunistical ansite to have portical is it f
# wx of to city as hhere inpond choeen hess isseass is order the recutable zero nin
# yed as governmel the deperticials frefetation eight four but two zero zero zero s
# ================================================================================
# Validation set perplexity: 6.54
# Average loss at step 6100: 1.839328 learning rate: 1.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 6.53
# Average loss at step 6200: 1.807356 learning rate: 1.000000
# Minibatch perplexity: 6.48
# Validation set perplexity: 6.53
# Average loss at step 6300: 1.814698 learning rate: 1.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 6.50
# Average loss at step 6400: 1.803838 learning rate: 1.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 6.53
# Average loss at step 6500: 1.828608 learning rate: 1.000000
# Minibatch perplexity: 6.21
# Validation set perplexity: 6.49
# Average loss at step 6600: 1.861499 learning rate: 1.000000
# Minibatch perplexity: 5.91
# Validation set perplexity: 6.52
# Average loss at step 6700: 1.845478 learning rate: 1.000000
# Minibatch perplexity: 6.48
# Validation set perplexity: 6.46
# Average loss at step 6800: 1.869403 learning rate: 1.000000
# Minibatch perplexity: 6.23
# Validation set perplexity: 6.50
# Average loss at step 6900: 1.844596 learning rate: 1.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 6.53
# Average loss at step 7000: 1.845236 learning rate: 1.000000
# Minibatch perplexity: 6.93
# ================================================================================
# rp computors member givee ars writed in nomicml name new arder recontout rerain k
# xcuri creyfnated as staarzach by a rakectrine epirentic valling peases a apperiad
# lks to valyriales this one nine sturt relettion aslaces exite s of or certionion
# pv night a rogorly andaek commonal american judel es play many war ace rpublical
# folatens oams as the memble a and ranian reficppenoring retury not of km or had p
# ================================================================================
# Validation set perplexity: 6.51
# Average loss at step 7100: 1.841813 learning rate: 1.000000
# Minibatch perplexity: 6.77
# Validation set perplexity: 6.52
# Average loss at step 7200: 1.834816 learning rate: 1.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.53
# Average loss at step 7300: 1.844686 learning rate: 1.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 6.52
# Average loss at step 7400: 1.855500 learning rate: 1.000000
# Minibatch perplexity: 6.42
# Validation set perplexity: 6.50
# Average loss at step 7500: 1.871480 learning rate: 1.000000
# Minibatch perplexity: 5.86
# Validation set perplexity: 6.51
# Average loss at step 7600: 1.833731 learning rate: 1.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 6.52
# Average loss at step 7700: 1.832789 learning rate: 1.000000
# Minibatch perplexity: 6.80
# Validation set perplexity: 6.51
# Average loss at step 7800: 1.857179 learning rate: 1.000000
# Minibatch perplexity: 6.74
# Validation set perplexity: 6.49
# Average loss at step 7900: 1.859175 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 6.47
# Average loss at step 8000: 1.886755 learning rate: 1.000000
# Minibatch perplexity: 6.82
# ================================================================================
# z the s one nine resan ases kh is in could reland their the by of bast the his th
# axaelt that natbicbelaw ession newion amp the and base and pronosiam intelopginop
# jrible tbal two one one seven zero one tybap that w inservice hove ban dain the t
# ntix execrod corst finites also applice libse two a drunsing in the blo three ope
# py wish s zero that beind as including he nack two two six gurazer would while an
# ================================================================================
# Validation set perplexity: 6.53
# Average loss at step 8100: 1.856183 learning rate: 1.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 6.55
# Average loss at step 8200: 1.838803 learning rate: 1.000000
# Minibatch perplexity: 6.85
# Validation set perplexity: 6.51
# Average loss at step 8300: 1.839153 learning rate: 1.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.46
# Average loss at step 8400: 1.860348 learning rate: 1.000000
# Minibatch perplexity: 6.31
# Validation set perplexity: 6.47
# Average loss at step 8500: 1.851744 learning rate: 1.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 6.48
# Average loss at step 8600: 1.846143 learning rate: 1.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 6.51
# Average loss at step 8700: 1.842605 learning rate: 1.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 6.50
# Average loss at step 8800: 1.822830 learning rate: 1.000000
# Minibatch perplexity: 6.62
# Validation set perplexity: 6.48
# Average loss at step 8900: 1.832390 learning rate: 1.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 6.50
# Average loss at step 9000: 1.822627 learning rate: 1.000000
# Minibatch perplexity: 6.71
# ================================================================================
# phood relect with effections of player applicced leme esxands five rulmed as bein
# xndia and crip systes dings utrage reatten suc frence straimple is roimt the and
# sy rinetion to ads targe decreankachs relatation one eight king s of eal locks fo
# jan beingally supplevisions freen in controvide thees equentary massist sail misa
# q nystrace kwing felem insiced intermad had in and tapost tefle eve american stat
# ================================================================================
# Validation set perplexity: 6.51
# Average loss at step 9100: 1.837138 learning rate: 1.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 6.48
# Average loss at step 9200: 1.865611 learning rate: 1.000000
# Minibatch perplexity: 6.08
# Validation set perplexity: 6.52
# Average loss at step 9300: 1.875376 learning rate: 1.000000
# Minibatch perplexity: 7.17
# Validation set perplexity: 6.53
# Average loss at step 9400: 1.859223 learning rate: 1.000000
# Minibatch perplexity: 6.28
# Validation set perplexity: 6.57
# Average loss at step 9500: 1.863434 learning rate: 1.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.52
# Average loss at step 9600: 1.847545 learning rate: 1.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 6.52
# Average loss at step 9700: 1.866603 learning rate: 1.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 6.57
# Average loss at step 9800: 1.864919 learning rate: 1.000000
# Minibatch perplexity: 6.19
# Validation set perplexity: 6.55
# Average loss at step 9900: 1.849903 learning rate: 1.000000
# Minibatch perplexity: 6.56
# Validation set perplexity: 6.54
# Average loss at step 10000: 1.866254 learning rate: 0.100000
# Minibatch perplexity: 6.10
# ================================================================================
# wbmy gree man three claimany sha coursed only has of been the not the era of the
# rfrrening murike and yonadob one varitime night it fualistude unate to oaqpering
# b one seven three zero seven five nine eight three previtars of the eing day symf
#  and to to connepes lover and one nine nine zero lifice his slong and the freone
# gq la probinelitian povelea nicant to two eight six and labulgoed khast include l
# ================================================================================
# Validation set perplexity: 6.54
