# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
import numpy as np
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'originated', 'as', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.195683
# Nearest to s: telnet, boyfriend, stockade, dembski, fan, trombones, meander, nov,
# Nearest to three: caches, kamehameha, attainment, wendell, handel, amplify, necessitate, sequel,
# Nearest to people: guarani, xilinx, legislated, mules, repelling, ia, tokyo, doctors,
# Nearest to six: grail, national, revise, hutch, returned, westinghouse, egmont, meantime,
# Nearest to in: worry, faramir, basel, stockton, surplus, hour, tarnished, anarchic,
# Nearest to seven: beano, phonemes, laughton, distributive, globes, repellent, understandably, dues,
# Nearest to united: neurotic, gogo, momentum, phagspa, tosses, immoral, masks, nan,
# Nearest to first: curie, ellipsoid, loyola, coffins, rewrite, expressed, childress, simmered,
# Nearest to was: zawahiri, ethnomusicology, harman, piston, overbearing, cockburn, huge, shankar,
# Nearest to but: evacuation, cardiac, crankshaft, casper, baluchistan, hinge, chained, nyu,
# Nearest to however: troposphere, analytic, interwiki, notion, pulp, tikal, tooth, overlaid,
# Nearest to all: portrayal, february, sega, fractal, theravada, besides, cj, constantinopolitan,
# Nearest to UNK: hello, norbert, infibulation, disclaimed, dare, dribbling, teen, macedonia,
# Nearest to would: fascists, formatting, width, discrepancies, yoshida, fibonacci, intellectual, leffler,
# Nearest to may: undergoes, sissy, discus, avril, rumour, almoravides, enveloped, attribution,
# Nearest to will: judges, itu, europeans, absurdities, weighted, ericaceae, prints, parliament,
# Average loss at step 2000: 4.370676
# Average loss at step 4000: 3.867398
# Average loss at step 6000: 3.787157
# Average loss at step 8000: 3.692362
# Average loss at step 10000: 3.621761
# Nearest to s: his, and, modena, bachelors, yachts, dembski, shortening, papua,
# Nearest to three: four, six, eight, five, seven, two, nine, zero,
# Nearest to people: earle, sectarianism, creep, roommates, legislated, xilinx, bounty, backspace,
# Nearest to six: eight, seven, three, four, nine, five, zero, two,
# Nearest to in: of, on, with, from, at, between, untold, and,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to united: phagspa, contenders, steadfastly, gogo, nationalization, momentum, ll, box,
# Nearest to first: captain, curie, bird, following, final, city, rabinowitz, intents,
# Nearest to was: is, has, had, by, were, be, are, became,
# Nearest to but: brood, wither, cardiac, or, and, palatal, ethica, valyria,
# Nearest to however: connors, delicacies, tooth, jenna, logistic, pulp, defection, when,
# Nearest to all: these, various, guzm, portrayal, unnecessarily, seaside, cygnus, salvatore,
# Nearest to UNK: torrey, disturbed, negro, anarchistic, apps, simon, kops, obscenity,
# Nearest to would: can, may, will, to, yoshida, dressing, apprentices, does,
# Nearest to may: might, would, can, undergoes, minurso, will, cleveland, avril,
# Nearest to will: can, should, would, must, leu, barthes, europeans, may,
# Average loss at step 12000: 3.607411
# Average loss at step 14000: 3.572273
# Average loss at step 16000: 3.414292
# Average loss at step 18000: 3.461924
# Average loss at step 20000: 3.539658
# Nearest to s: biologically, ipv, the, duryodhana, and, domini, spook, rusty,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to people: earle, nighthawk, creep, sectarianism, bounty, torment, interacts, roommates,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to in: at, on, from, with, for, through, under, and,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to united: same, steadfastly, box, contenders, phagspa, folds, late, following,
# Nearest to first: following, rabinowitz, same, second, windward, lutetium, reinstating, ayers,
# Nearest to was: is, were, has, had, became, be, are, been,
# Nearest to but: however, and, although, does, when, though, or, consider,
# Nearest to however: but, which, when, delicacies, connors, tooth, purportedly, that,
# Nearest to all: these, various, many, some, guzm, seaside, several, most,
# Nearest to UNK: sensuous, iga, tanzania, orangutan, poet, o, designated, simon,
# Nearest to would: can, may, will, could, should, to, must, does,
# Nearest to may: can, would, might, will, could, must, should, minurso,
# Nearest to will: would, can, must, should, may, could, barthes, bedi,
# Average loss at step 22000: 3.510633
# Average loss at step 24000: 3.488473
# Average loss at step 26000: 3.482385
# Average loss at step 28000: 3.485400
# Average loss at step 30000: 3.505490
# Nearest to s: modena, his, isbn, ipv, integrable, definite, domini, realise,
# Nearest to three: four, five, seven, six, eight, two, zero, nine,
# Nearest to people: creep, interacts, bounty, earle, nighthawk, those, others, encircle,
# Nearest to six: eight, four, seven, nine, five, three, zero, two,
# Nearest to in: on, during, under, at, of, until, from, with,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to united: same, folds, tosses, box, late, gogo, careers, steadfastly,
# Nearest to first: second, last, same, original, rabinowitz, salom, cosworth, final,
# Nearest to was: is, had, has, were, became, been, when, be,
# Nearest to but: however, although, and, though, when, while, ethica, or,
# Nearest to however: but, when, errands, although, which, purportedly, then, mulcahy,
# Nearest to all: these, various, many, some, several, both, instead, most,
# Nearest to UNK: solomon, admin, iga, agave, rested, tyndall, anders, terran,
# Nearest to would: can, may, could, will, should, must, might, to,
# Nearest to may: can, would, might, will, could, should, must, minurso,
# Nearest to will: can, would, may, should, must, could, barthes, shall,
# Average loss at step 32000: 3.498745
# Average loss at step 34000: 3.495602
# Average loss at step 36000: 3.457086
# Average loss at step 38000: 3.304417
# Average loss at step 40000: 3.429103
# Nearest to s: grants, his, her, informant, modena, akira, odor, clerics,
# Nearest to three: four, five, two, seven, six, eight, nine, zero,
# Nearest to people: interacts, others, individuals, externalization, those, languages, islamabad, ugly,
# Nearest to six: four, five, seven, eight, nine, three, zero, two,
# Nearest to in: of, on, from, and, amg, at, with, within,
# Nearest to seven: eight, five, nine, six, four, three, zero, one,
# Nearest to united: folds, late, tosses, rediscovery, same, careers, atmosphere, gogo,
# Nearest to first: second, last, salom, next, final, same, doubting, fourth,
# Nearest to was: is, became, were, had, has, been, be, did,
# Nearest to but: however, although, and, though, when, where, it, he,
# Nearest to however: but, that, although, errands, which, mulcahy, then, though,
# Nearest to all: both, these, various, many, several, some, donnell, two,
# Nearest to UNK: e, b, j, alexander, h, iraqis, ono, monika,
# Nearest to would: can, could, may, will, should, might, must, did,
# Nearest to may: can, would, will, could, might, should, must, opulent,
# Nearest to will: can, would, may, could, should, must, might, shall,
# Average loss at step 42000: 3.431177
# Average loss at step 44000: 3.456081
# Average loss at step 46000: 3.453444
# Average loss at step 48000: 3.356399
# Average loss at step 50000: 3.388365
# Nearest to s: and, addressing, biologically, his, its, mnr, jonson, bernard,
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to people: men, children, ugly, individuals, interacts, others, koran, them,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to in: between, on, during, amg, from, at, until, within,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to united: tosses, folds, careers, atmosphere, rediscovery, late, same, teddy,
# Nearest to first: second, last, final, next, fourth, same, doubting, salom,
# Nearest to was: is, has, were, became, had, been, becomes, be,
# Nearest to but: however, although, when, though, and, while, during, schedel,
# Nearest to however: but, although, that, though, when, errands, while, where,
# Nearest to all: both, various, these, many, lambdamoo, puff, portrayal, any,
# Nearest to UNK: tau, townsend, com, playback, pectoral, gmt, renouncing, infrastructural,
# Nearest to would: could, can, may, will, should, must, might, does,
# Nearest to may: can, would, should, will, could, might, must, cannot,
# Nearest to will: can, would, could, may, should, must, might, shall,
# Average loss at step 52000: 3.433564
# Average loss at step 54000: 3.428456
# Average loss at step 56000: 3.438453
# Average loss at step 58000: 3.396557
# Average loss at step 60000: 3.395242
# Nearest to s: grants, addressing, glutamate, whose, expellees, lexicology, brontosaurus, roberta,
# Nearest to three: four, five, six, two, eight, seven, nine, zero,
# Nearest to people: men, those, individuals, others, interacts, ugly, children, christians,
# Nearest to six: eight, five, four, nine, seven, three, two, zero,
# Nearest to in: within, during, of, at, including, since, hysterical, between,
# Nearest to seven: eight, five, four, nine, six, three, zero, two,
# Nearest to united: rediscovery, tosses, atmosphere, careers, folds, livermore, late, constructors,
# Nearest to first: second, last, final, next, same, frustration, fourth, salom,
# Nearest to was: is, became, had, has, were, although, does, been,
# Nearest to but: however, although, and, though, were, than, when, which,
# Nearest to however: but, although, errands, that, though, which, when, since,
# Nearest to all: both, various, many, these, those, any, some, kush,
# Nearest to UNK: headless, temporal, borzoi, http, pki, ichi, dreary, lumen,
# Nearest to would: could, will, may, can, should, might, must, does,
# Nearest to may: can, would, will, should, might, could, must, cannot,
# Nearest to will: would, can, could, may, should, must, might, shall,
# Average loss at step 62000: 3.237679
# Average loss at step 64000: 3.256045
# Average loss at step 66000: 3.406709
# Average loss at step 68000: 3.393657
# Average loss at step 70000: 3.357648
# Nearest to s: glutamate, brontosaurus, whose, modena, meteorological, jonson, isbn, winger,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to people: men, others, those, individuals, ugly, cases, children, scientists,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to in: within, on, for, during, between, trygve, until, including,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to united: atmosphere, rediscovery, careers, same, tosses, grissom, basing, folds,
# Nearest to first: second, last, next, final, same, fourth, best, original,
# Nearest to was: is, were, has, had, became, been, be, becomes,
# Nearest to but: however, although, which, though, and, that, erupted, while,
# Nearest to however: but, although, though, that, where, while, errands, when,
# Nearest to all: some, various, many, any, every, both, these, those,
# Nearest to UNK: tyndall, mess, resources, tau, independently, illnesses, jimmy, gmt,
# Nearest to would: will, could, may, can, should, might, must, did,
# Nearest to may: can, would, will, should, could, might, must, cannot,
# Nearest to will: would, could, can, may, should, must, might, shall,
# Average loss at step 72000: 3.376908
# Average loss at step 74000: 3.347411
# Average loss at step 76000: 3.312403
# Average loss at step 78000: 3.351909
# Average loss at step 80000: 3.380757
# Nearest to s: kriol, dr, fpga, isbn, brontosaurus, bernard, kc, greyhound,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to people: men, others, individuals, cases, children, someone, those, christians,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to in: during, within, until, since, at, on, of, between,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to united: atmosphere, rediscovery, same, careers, basing, tosses, prc, grissom,
# Nearest to first: second, last, next, fourth, third, final, salom, same,
# Nearest to was: is, became, were, has, had, becomes, been, hypnotherapy,
# Nearest to but: however, although, though, and, while, which, than, does,
# Nearest to however: although, but, that, though, while, errands, when, where,
# Nearest to all: both, every, various, any, some, many, these, kush,
# Nearest to UNK: jones, simon, na, ono, h, gmt, smith, firewood,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to may: can, would, should, will, could, might, must, cannot,
# Nearest to will: would, can, could, may, should, must, might, shall,
# Average loss at step 82000: 3.408855
# Average loss at step 84000: 3.414846
# Average loss at step 86000: 3.390935
# Average loss at step 88000: 3.353153
# Average loss at step 90000: 3.366890
# Nearest to s: whose, isbn, his, brontosaurus, writs, franconia, leonard, rada,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to people: men, children, someone, individuals, ugly, christians, others, women,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to in: within, during, under, until, at, around, with, on,
# Nearest to seven: eight, five, four, nine, six, three, zero, two,
# Nearest to united: atmosphere, rediscovery, tosses, same, basing, careers, prc, folds,
# Nearest to first: second, last, final, salom, original, same, entire, next,
# Nearest to was: is, had, became, were, has, be, been, becomes,
# Nearest to but: however, and, although, though, which, while, that, he,
# Nearest to however: but, although, that, though, while, especially, errands, since,
# Nearest to all: both, many, various, every, any, several, these, some,
# Nearest to UNK: tyndall, kops, powerbook, neanderthalensis, ek, na, filking, anac,
# Nearest to would: could, will, may, can, might, must, should, did,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Average loss at step 92000: 3.399330
# Average loss at step 94000: 3.253751
# Average loss at step 96000: 3.361053
# Average loss at step 98000: 3.242721
# Average loss at step 100000: 3.360350
# Nearest to s: whose, isbn, his, jonson, ljubljana, brontosaurus, duryodhana, buster,
# Nearest to three: four, five, seven, two, eight, six, nine, zero,
# Nearest to people: children, men, someone, individuals, others, students, christians, ugly,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to in: within, during, until, from, on, at, near, into,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to united: atmosphere, rediscovery, constitution, same, tosses, prc, careers, grissom,
# Nearest to first: last, second, next, third, fourth, final, same, moshiach,
# Nearest to was: is, became, had, has, were, been, becomes, when,
# Nearest to but: however, although, and, though, which, while, passionately, that,
# Nearest to however: but, although, that, though, especially, while, and, errands,
# Nearest to all: many, various, several, these, some, every, any, both,
# Nearest to UNK: gul, forerunner, ack, independently, murmur, townsend, vite, ve,
# Nearest to would: could, will, may, might, can, must, should, did,
# Nearest to may: can, could, would, might, should, must, will, cannot,
# Nearest to will: would, can, could, must, should, may, might, shall,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
